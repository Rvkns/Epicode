# %%
import matplotlib.pyplot as plt
from plotly import express as px

# %%
stocks = px.data.stocks()

# %%
stocks #visualizziamo il dataset
# Out:
#            date      GOOG      AAPL      AMZN        FB      NFLX      MSFT
# 0    2018-01-01  1.000000  1.000000  1.000000  1.000000  1.000000  1.000000
# 1    2018-01-08  1.018172  1.011943  1.061881  0.959968  1.053526  1.015988
# 2    2018-01-15  1.032008  1.019771  1.053240  0.970243  1.049860  1.020524
# 3    2018-01-22  1.066783  0.980057  1.140676  1.016858  1.307681  1.066561
# 4    2018-01-29  1.008773  0.917143  1.163374  1.018357  1.273537  1.040708
# ..          ...       ...       ...       ...       ...       ...       ...
# 100  2019-12-02  1.216280  1.546914  1.425061  1.075997  1.463641  1.720717
# 101  2019-12-09  1.222821  1.572286  1.432660  1.038855  1.421496  1.752239
# 102  2019-12-16  1.224418  1.596800  1.453455  1.104094  1.604362  1.784896
# 103  2019-12-23  1.226504  1.656000  1.521226  1.113728  1.567170  1.802472
# 104  2019-12-30  1.213014  1.678000  1.503360  1.098475  1.540883  1.788185
#
# [105 rows x 7 columns]

# %%
stocks.head(5) #visualizziamo le prime cinque righe del dataset
# Out:
#          date      GOOG      AAPL      AMZN        FB      NFLX      MSFT
# 0  2018-01-01  1.000000  1.000000  1.000000  1.000000  1.000000  1.000000
# 1  2018-01-08  1.018172  1.011943  1.061881  0.959968  1.053526  1.015988
# 2  2018-01-15  1.032008  1.019771  1.053240  0.970243  1.049860  1.020524
# 3  2018-01-22  1.066783  0.980057  1.140676  1.016858  1.307681  1.066561
# 4  2018-01-29  1.008773  0.917143  1.163374  1.018357  1.273537  1.040708

# %%
goog = stocks['GOOG']
data = stocks['date']
#isoliamo in due variabili differenti le colonne che ci interessano, in questo caso le azioni di Google e le date

# %%
goog
# Out:
# 0      1.000000
# 1      1.018172
# 2      1.032008
# 3      1.066783
# 4      1.008773
#          ...
# 100    1.216280
# 101    1.222821
# 102    1.224418
# 103    1.226504
# 104    1.213014
# Name: GOOG, Length: 105, dtype: float64

# %%
data
# Out:
# 0      2018-01-01
# 1      2018-01-08
# 2      2018-01-15
# 3      2018-01-22
# 4      2018-01-29
#           ...
# 100    2019-12-02
# 101    2019-12-09
# 102    2019-12-16
# 103    2019-12-23
# 104    2019-12-30
# Name: date, Length: 105, dtype: object

# %%
goog = stocks['GOOG'][:5]
data = stocks['date'][:5]
#immagaziniamo nelle due variabili di riferimento soltanto le prime cinque righe delle colonne indicate

# %%
#creiamo un grafico per i primi cinque records, impostando:
plt.figure(figsize=(10, 6)) #parametri di grandezza del grafico
plt.plot(data, goog, marker='*', linestyle='-') #parametri del grafico(dati, stile del marker, stile della linea)
plt.xlabel('Periodo di riferimento') 
plt.ylabel('Prezzo azioni Google')
plt.title('Andamento delle azioni di Google(Primi cinque records)')
#i vari titoli dell'asse X, Y e del grafico generale
plt.xticks(rotation=90) #orientiamo a 90° i nomi dell'asse X per evitare sovrapposizioni
plt.grid(False) #eliminiamo la griglia che potrebbe risultare scomoda
plt.show() #mostriamo il grafico

# %%
goog2 = stocks['GOOG'][-5:]
data2 = stocks['date'][-5:]
#immagaziniamo gli ultimi cinque records in due variabili diverse, per evitare di sovrascrivere quelle precedenti

# %%
goog2
# Out:
# 100    1.216280
# 101    1.222821
# 102    1.224418
# 103    1.226504
# 104    1.213014
# Name: GOOG, dtype: float64

# %%
data2
# Out:
# 100    2019-12-02
# 101    2019-12-09
# 102    2019-12-16
# 103    2019-12-23
# 104    2019-12-30
# Name: date, dtype: object

# %%
plt.figure(figsize=(10, 6))
plt.plot(data2, goog2, marker='s', linestyle='-')
plt.xlabel('Periodo di riferimento')
plt.ylabel('Prezzo azioni Google')
plt.title('Andamento delle azioni di Google(Ultimi cinque records)')
plt.xticks(rotation=90)
plt.grid(False)
plt.show()

# %%
stocks
# Out:
#            date      GOOG      AAPL      AMZN        FB      NFLX      MSFT
# 0    2018-01-01  1.000000  1.000000  1.000000  1.000000  1.000000  1.000000
# 1    2018-01-08  1.018172  1.011943  1.061881  0.959968  1.053526  1.015988
# 2    2018-01-15  1.032008  1.019771  1.053240  0.970243  1.049860  1.020524
# 3    2018-01-22  1.066783  0.980057  1.140676  1.016858  1.307681  1.066561
# 4    2018-01-29  1.008773  0.917143  1.163374  1.018357  1.273537  1.040708
# ..          ...       ...       ...       ...       ...       ...       ...
# 100  2019-12-02  1.216280  1.546914  1.425061  1.075997  1.463641  1.720717
# 101  2019-12-09  1.222821  1.572286  1.432660  1.038855  1.421496  1.752239
# 102  2019-12-16  1.224418  1.596800  1.453455  1.104094  1.604362  1.784896
# 103  2019-12-23  1.226504  1.656000  1.521226  1.113728  1.567170  1.802472
# 104  2019-12-30  1.213014  1.678000  1.503360  1.098475  1.540883  1.788185
#
# [105 rows x 7 columns]

# %%
apple = stocks['AAPL'][:20]
data3 = stocks['date'][:20]
#immagaziniamo i primi 20 records delle date e delle azioni Apple

# %%
apple
# Out:
# 0     1.000000
# 1     1.011943
# 2     1.019771
# 3     0.980057
# 4     0.917143
# 5     0.893771
# 6     0.985314
# 7     1.002857
# 8     1.006914
# 9     1.028457
# 10    1.017257
# 11    0.942514
# 12    0.958743
# 13    0.962171
# 14    0.998457
# 15    0.946971
# 16    0.927543
# 17    1.050457
# 18    1.077657
# 19    1.064629
# Name: AAPL, dtype: float64

# %%
data3
# Out:
# 0     2018-01-01
# 1     2018-01-08
# 2     2018-01-15
# 3     2018-01-22
# 4     2018-01-29
# 5     2018-02-05
# 6     2018-02-12
# 7     2018-02-19
# 8     2018-02-26
# 9     2018-03-05
# 10    2018-03-12
# 11    2018-03-19
# 12    2018-03-26
# 13    2018-04-02
# 14    2018-04-09
# 15    2018-04-16
# 16    2018-04-23
# 17    2018-04-30
# 18    2018-05-07
# 19    2018-05-14
# Name: date, dtype: object

# %%
plt.figure(figsize=(10, 6))
plt.plot(data3, apple, marker='o', linestyle='--', color='Red', markerfacecolor='Black', linewidth=2 )
plt.xlabel('Data')
plt.ylabel('Valore')
plt.title('Azioni Apple')
plt.xticks(rotation=90)
plt.grid(False)
plt.tight_layout()
plt.show()

# %%
stocks
# Out:
#            date      GOOG      AAPL      AMZN        FB      NFLX      MSFT
# 0    2018-01-01  1.000000  1.000000  1.000000  1.000000  1.000000  1.000000
# 1    2018-01-08  1.018172  1.011943  1.061881  0.959968  1.053526  1.015988
# 2    2018-01-15  1.032008  1.019771  1.053240  0.970243  1.049860  1.020524
# 3    2018-01-22  1.066783  0.980057  1.140676  1.016858  1.307681  1.066561
# 4    2018-01-29  1.008773  0.917143  1.163374  1.018357  1.273537  1.040708
# ..          ...       ...       ...       ...       ...       ...       ...
# 100  2019-12-02  1.216280  1.546914  1.425061  1.075997  1.463641  1.720717
# 101  2019-12-09  1.222821  1.572286  1.432660  1.038855  1.421496  1.752239
# 102  2019-12-16  1.224418  1.596800  1.453455  1.104094  1.604362  1.784896
# 103  2019-12-23  1.226504  1.656000  1.521226  1.113728  1.567170  1.802472
# 104  2019-12-30  1.213014  1.678000  1.503360  1.098475  1.540883  1.788185
#
# [105 rows x 7 columns]

# %%
azioni = stocks.columns[1:]
azioni
# Out:
# Index(['GOOG', 'AAPL', 'AMZN', 'FB', 'NFLX', 'MSFT'], dtype='object')

# %%
plt.figure(figsize=(10,6))
colors = ['red','blue','green','yellow','purple','black','orange']
for col,titoli in enumerate(azioni):
    plt.plot(stocks['date'], stocks[titoli], linestyle='-', linewidth=2, color=colors[col], markerfacecolor="Black")
#facciamo iterare due variabili, una per visualizzare tutti i titoli ed una per cambiargli colore.
#in questo caso abbiamo usato la colonna 'date' come riferimento univoco per i periodi storici e la variabile 'titoli' 
#che contiene l'iterazione delle azioni precedentemente selezionate
plt.xlabel('Periodo di riferimento')
plt.ylabel('Valore delle azioni')
plt.title('Andamento azioni')
plt.xticks(rotation=90, fontsize=5.5) #cambiamo il font dei ticks dell'asse X per evitare 
plt.grid(False)
plt.legend(azioni, loc='lower right', fontsize=8)
plt.tight_layout()

plt.show()
